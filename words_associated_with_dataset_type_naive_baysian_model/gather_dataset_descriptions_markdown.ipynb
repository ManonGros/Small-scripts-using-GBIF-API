# %%
import pandas as pd
import json
import requests
import random
import textblob
from textblob.classifiers import NaiveBayesClassifier

# %% [markdown]
# # Are there any keywords associated with a dataset type?
#
# With the help of the [GBIF API](https://www.gbif.org/developer/summary) and textblob.
#
# See the documentation I used to write this little script:
# * https://www.analyticsvidhya.com/blog/2018/02/the-different-methods-deal-text-data-predictive-python/
# * https://stevenloria.com/simple-text-classification/
#
# ## I - get the dataset's features to analyse from GBIF

# %%
res = pd.DataFrame(columns=["Title", "Description", "type"])

# We are excluding datasets from organizations that generated the metadata automatically
# PLAZI, GEO-TER and PANGEA
exclude = ['7ce8aef0-9e92-11dc-8738-b8a03c50a862',
           'd5778510-eb28-11da-8629-b8a03c50a862',
           'ef69a030-3940-11dd-b168-b8a03c50a862']
offset = 0
step = 900
end_of_records = False
while not end_of_records:
    param = {
        "offset": offset,
        "limit": step
    }
    # Query API
    response = requests.get("http://api.gbif.org/v1/dataset", param)
    response = response.json()
    offset += step
    end_of_records = response["endOfRecords"]
    for dataset in response["results"]:
        # exclude dataset from PLAZI, GEO-TER and PANGEA
        if dataset["publishingOrganizationKey"] not in exclude:
            # Get title and description of the dataset
            res.at[dataset["key"], "Title"] = dataset["title"]
            if "description" in dataset:
                res.at[dataset["key"], "Description"] = dataset["description"]
            else:
                res.at[dataset["key"], "Description"] = ""
            res.at[dataset["key"], "type"] = dataset["type"]

# %% [markdown]
# ## II - Set the parameters for the cleaning and analysis

# %%
feature = "Description" # we want to find words in the description
ferquency_threshold = 50 # how many most frequent word do we remove
rare_threshold_word_number = 15 # how many time a word should appear to be kept
size_training_set = 5000 # training set size

# %% [markdown]
# ## III - Clean up

# %%
# Set everything to lower case
res[feature] = res[feature].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
# Remove punctuation
res[feature] = res[feature].str.replace('[^\w\s]', '')

# Remove taboo words (which could give bout the dataset type)
taboo_words = ["checklist", "occurrence", "event"]
for taboo in taboo_words:
    res[feature] = res[feature].str.replace(taboo, '')

# %%
# Find the most frequent words
freq = pd.Series(' '.join(res[feature]).split()).value_counts()[:ferquency_threshold]
# print(freq)
freq = list(freq.index)
# Remove the most frequent words
for taboo in freq:
    res[feature] = res[feature].replace(taboo, '')

# %%
# Find the rare words
freq = pd.Series(' '.join(res[feature]).split()).value_counts()
freq = freq[freq < rare_threshold_word_number]
freq = list(freq.index)
# Remove rare words
for taboo in freq:
    res[feature] = res[feature].replace(taboo, '')

# %%
# Correct spelling - not done here because it takes too much time
# res['Title'] = res['Title'].apply(lambda x: str(textblob.TextBlob(x).correct()))

# %%
# Lemmatization (remove some letters in words to make it more "universal")
res[feature] = res[feature].apply(lambda x: " ".join([textblob.Word(word).lemmatize() for word in x.split()]))

# %%
# Reformat dataset
dataset = list(res[[feature, 'type']].itertuples(index=False))
# Shuffle data
random.shuffle(dataset)

# %% [markdown]
# ## IV - Train and test Classifier - Naive Bayesian

# %%
# Train classifier
cl = NaiveBayesClassifier(dataset[0:size_training_set])

# %%
# Test classifier
cl.accuracy(dataset[size_training_set:])
# Out:
# 0.8605159597726278

# %%
# Put back the performance in the context 
# In our case the performance is barely any better than predicting the most abundant class:
# See numbers below, 83% of the datasets are occurrence datasets
res["type"].value_counts()
# Out:
# OCCURRENCE        7985
# CHECKLIST         1159
# METADATA           220
# SAMPLING_EVENT     210
# Name: type, dtype: int64

# %% [markdown]
# Over all **this model is not good**. I would conclude that there isnt any good way to infer the dataset type from the metadata.
#
# In addition to this, no particular relevant word is clearly associated to a data type (see below).
#
# ## V - What word is associated with a dataset type

# %%
# Find the most informative words
cl.show_informative_features(10)
# Out:
# Most Informative Features
# contains(httpswwwndffnlenglish) = True           METADA : OCCURR =   1477.9 : 1.0
#       contains(positive) = True           METADA : OCCURR =    901.7 : 1.0
#     contains(evaluating) = True           SAMPLI : OCCURR =    418.4 : 1.0
#            contains(fim) = True           SAMPLI : OCCURR =    395.8 : 1.0
#    contains(utilization) = True           SAMPLI : OCCURR =    264.6 : 1.0
#        contains(without) = True           METADA : OCCURR =    170.9 : 1.0
#       contains(overseas) = True           CHECKL : OCCURR =    170.4 : 1.0
#            contains(cbd) = True           CHECKL : OCCURR =    161.0 : 1.0
#        contains(flagged) = True           CHECKL : OCCURR =    147.0 : 1.0
#      contains(kilometre) = True           METADA : OCCURR =    136.6 : 1.0

# %%
# Example to check out datasets containing one of the informative words: positive
res[res.Description.str.contains("positive")] # In most cases here, they are artifacts
# Out:
#                                                                                   Title  \
# bbcdfbfc-d1d5-4ba1-a56f-bc4c96150a2f        Leopard and Weddell seal program  1999/2002
# f83746ee-4cf2-4e60-a720-dd508b559794                                      NDFF Waternet
# 09683b92-d4e8-4773-9959-e07ff47167f5                           NDFF Unie van Bosgroepen
# 99f3136c-d582-45a7-8b93-67c5ec52daab                                 NDFF City of Breda
# 405f09d2-17a5-4630-b08a-052ae49510a4                              NDFF City of Deventer
# 19e38826-ec3d-481f-bd19-57f5e7e8c17c                      NDFF Delfland Water Authority
# ffae2921-22c7-41e4-a0d2-41a33f0aeb2a                      NDFF Rijnland Water Authority
# cd2dd66d-d1c4-4512-a6d1-4048601572c8      NDFF Water Authority Schieland Krimpenerwaard
# d4974c0d-0e3b-49e4-ab7b-46c697a634f2      NDFF Water Authority Hollands Noorderkwartier
# a4c3bfc2-9443-4cf5-ba56-fae8eb1aca6e  NDFF Monitoring program vascular plants in EU ...
# acd35cdb-9ae6-4a77-9392-54e6c070bc3e             NDFF Amphibian monitoring program 2001
# f9277135-91a7-4d63-9ce4-0eac99dc85e2             NDFF Amphibian monitoring program 2011
# 7d28fe9c-190a-43ab-bdf8-a7235490bbf4             NDFF Amphibian monitoring program 2015
# 4b62872b-a3eb-4737-8388-cab09c747a81                      NDFF Transect counts for bats
# 616efc67-5aba-49f7-914d-8c2c8e217858  NDFF Distribution survey Eurasian beaver and E...
# a3f72aa8-43a0-4146-87a3-a64f4c8dfd26  NDFF Lichens on stony substrates heathlands an...
# d88ff1b1-8ae9-4211-93ee-5c5931f164f2                       NDFF Hamatocaulis vernicosus
# d7bb3e9a-bf7a-44b1-81ca-72896a6d3b9c                                       NDFF DAZ BMP
# 3b4c5dda-728c-448b-9e45-41ddb14d28f3        NDFF Lichens on church walls and cemeteries
# 73a6191c-9855-41d1-9d41-01a7f2f5c3bb  NDFF monitoring epiphytic lichens and moss spe...
# ce326dad-c069-47b1-84bd-b74937ff37f1                                 NDFF Pellet survey
# 3805d974-905b-428e-be7b-a12aa1165f41                   NDFF Mice survey with live traps
# 72fd77c6-7729-4d2c-8c74-ea7f84779604  the city of eindhoven is the fifth largest cit...
# 06f85ca2-2efa-4d6d-a6da-32dbe78c0e5f  de dommel water board encompasses the river ba...
# 2d557a49-254a-4943-be50-0310af0b1e4b  groninger landschap dedicates itself to the co...
# 8883c92b-b29c-44f0-a49c-6f0f9735887b  the province of overijssel lie in the east of ...
# cbbd9fb2-42a3-479f-9d90-b42af448c058  the hollandse delta water authority manages a ...
# 7048932c-8838-4365-85b8-0bc6403ba5da  the hunze and aa water board resulted from a l...
# 71b3d75b-d46b-42dc-bb27-f73916e8c293  the brabantse delta water board manages an are...
# 950d5f27-61c9-457d-bc81-81375a697c70  zuidhollands landschap is a nature conservatio...
# 8ca4bbbc-c1c1-42c4-a70f-d4124ae1e754  pthe province of flevoland lie in the middle o...
# 27e0346a-db20-4bf0-a403-bda22ff70c7f  drenthe lie in the northeast of the netherland...
# 469805e0-b421-4323-9e6b-7bce132c92c5  the aim of the nem dragonfly monitoring progra...
# 449c706d-4175-46de-a499-f6e57e7fddaa  prorail the agency that manages rail infrastru...
# 01400d26-d164-473a-9a1c-818af8755a0c  the province of noordholland lie in the northw...
# e2a39a57-866f-4b1a-9974-6d5215282603  utrecht landschap wa established in 1927 and o...
# ad7295e0-3261-4028-8308-b2047d51d408  pthe province of noordbrabant lie in the south...
# ac37b606-c137-45c6-9ea3-0ff431a06e83  this is the water board of the province of lim...
# 901eda35-f16c-4f18-a3f4-49f00c1e7653  het flevolandschap is an organisation that pro...
# 031c4769-81bc-41ea-bd4f-823341a190cc  this monitoring program focus on all breeding ...
# 05833931-6559-47e5-97c1-a2242bc0f3b0  observation portal for voluntary observer admi...
# 2912f89b-4104-4dd7-a5fc-bbe45884cdbc  this dataset comprises all of the reptile reco...
# 9d481c56-ad91-43b1-8726-3e677009746d  black grouse number in south east scotland fel...
# 4cb30996-cc6a-44b9-b0c6-fce6f109d41f  each record indicates that water vole are pres...
# 3b778b3e-c784-4df6-bd89-364e0ab503ed  community assembly is an integral process in a...
# e0d1ce44-728d-4d0b-a303-41d151c5d4cf  psurvey of fish specie in berlin based on catc...
# 2a1ee347-adba-4743-bece-9c1d8171638d  the rhytismatales commonly referred to a tarsp...
# 530feb0e-61cd-4058-bb50-328e2230ea82  a new specie of vigna savi subgenus ceratotrop...
#
#                                                 type
# bbcdfbfc-d1d5-4ba1-a56f-bc4c96150a2f      OCCURRENCE
# f83746ee-4cf2-4e60-a720-dd508b559794        METADATA
# 09683b92-d4e8-4773-9959-e07ff47167f5        METADATA
# 99f3136c-d582-45a7-8b93-67c5ec52daab        METADATA
# 405f09d2-17a5-4630-b08a-052ae49510a4        METADATA
# 19e38826-ec3d-481f-bd19-57f5e7e8c17c        METADATA
# ffae2921-22c7-41e4-a0d2-41a33f0aeb2a        METADATA
# cd2dd66d-d1c4-4512-a6d1-4048601572c8        METADATA
# d4974c0d-0e3b-49e4-ab7b-46c697a634f2        METADATA
# a4c3bfc2-9443-4cf5-ba56-fae8eb1aca6e        METADATA
# acd35cdb-9ae6-4a77-9392-54e6c070bc3e        METADATA
# f9277135-91a7-4d63-9ce4-0eac99dc85e2        METADATA
# 7d28fe9c-190a-43ab-bdf8-a7235490bbf4        METADATA
# 4b62872b-a3eb-4737-8388-cab09c747a81        METADATA
# 616efc67-5aba-49f7-914d-8c2c8e217858        METADATA
# a3f72aa8-43a0-4146-87a3-a64f4c8dfd26        METADATA
# d88ff1b1-8ae9-4211-93ee-5c5931f164f2        METADATA
# d7bb3e9a-bf7a-44b1-81ca-72896a6d3b9c        METADATA
# 3b4c5dda-728c-448b-9e45-41ddb14d28f3        METADATA
# 73a6191c-9855-41d1-9d41-01a7f2f5c3bb        METADATA
# ce326dad-c069-47b1-84bd-b74937ff37f1        METADATA
# 3805d974-905b-428e-be7b-a12aa1165f41        METADATA
# 5d4911e4-8c8e-41cb-97ff-d80b2f11a4cc        METADATA
# 4b6d4f6c-e5d7-47bc-acaf-f507fb8a4077        METADATA
# 1b9d33a7-f5de-4616-884e-139de139801c        METADATA
# 04fd9faf-53aa-4057-b1dc-42a7718742aa        METADATA
# 2abdd78e-eddd-492f-90e4-47c55ec43e8b        METADATA
# 5cb5caa1-4b65-4d79-b38a-a6175e47ebda        METADATA
# 79ba4dfc-0135-4b46-a9cd-09699ba8d04b        METADATA
# 465ac814-ad9c-482c-a150-80d298bb1de1        METADATA
# ...                                              ...
# d1091599-ec94-4911-9c58-a5b0dcdfd772        METADATA
# d43f7c7f-3e32-4960-979b-996b8e47b986        METADATA
# 9067a32d-9315-4736-9522-9707cc108012        METADATA
# fda5ee54-cd11-4da7-9314-0d328f1ccfda        METADATA
# 72fd77c6-7729-4d2c-8c74-ea7f84779604        METADATA
# 06f85ca2-2efa-4d6d-a6da-32dbe78c0e5f        METADATA
# 2d557a49-254a-4943-be50-0310af0b1e4b        METADATA
# 8883c92b-b29c-44f0-a49c-6f0f9735887b        METADATA
# cbbd9fb2-42a3-479f-9d90-b42af448c058        METADATA
# 7048932c-8838-4365-85b8-0bc6403ba5da        METADATA
# 71b3d75b-d46b-42dc-bb27-f73916e8c293        METADATA
# 950d5f27-61c9-457d-bc81-81375a697c70        METADATA
# 8ca4bbbc-c1c1-42c4-a70f-d4124ae1e754        METADATA
# 27e0346a-db20-4bf0-a403-bda22ff70c7f        METADATA
# 469805e0-b421-4323-9e6b-7bce132c92c5        METADATA
# 449c706d-4175-46de-a499-f6e57e7fddaa        METADATA
# 01400d26-d164-473a-9a1c-818af8755a0c        METADATA
# e2a39a57-866f-4b1a-9974-6d5215282603        METADATA
# ad7295e0-3261-4028-8308-b2047d51d408        METADATA
# ac37b606-c137-45c6-9ea3-0ff431a06e83        METADATA
# 901eda35-f16c-4f18-a3f4-49f00c1e7653        METADATA
# 031c4769-81bc-41ea-bd4f-823341a190cc        METADATA
# 05833931-6559-47e5-97c1-a2242bc0f3b0        METADATA
# 2912f89b-4104-4dd7-a5fc-bbe45884cdbc      OCCURRENCE
# 9d481c56-ad91-43b1-8726-3e677009746d      OCCURRENCE
# 4cb30996-cc6a-44b9-b0c6-fce6f109d41f      OCCURRENCE
# 3b778b3e-c784-4df6-bd89-364e0ab503ed  SAMPLING_EVENT
# e0d1ce44-728d-4d0b-a303-41d151c5d4cf      OCCURRENCE
# 2a1ee347-adba-4743-bece-9c1d8171638d       CHECKLIST
# 530feb0e-61cd-4058-bb50-328e2230ea82       CHECKLIST
#
# [141 rows x 3 columns]
